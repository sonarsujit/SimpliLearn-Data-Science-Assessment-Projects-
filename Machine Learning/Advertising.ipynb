# %%
import pandas as pd
import numpy as np

# %%
df_ad = pd.read_csv('Advertising.csv')

# %%
df_ad.shape
# Out:
# (200, 4)

# %%
df_ad.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
df_ad.isnull().sum()
# Out:
# TV           0
# radio        0
# newspaper    0
# sales        0
# dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
fig,axs = plt.subplots(1,3,sharey=True, figsize=(15,8))
sns.scatterplot(data=df_ad, x='TV', y='sales', ax=axs[0])
sns.scatterplot(data=df_ad, x='radio', y='sales',ax=axs[1])
sns.scatterplot(data=df_ad, x='newspaper', y='sales',ax=axs[2])
plt.show()

# %%
#Observation
#looking at the scatter plots, we see that that 
# there is a +ve corelation between sales and TV and radio but appears no much corelation between salea nd newspaper

# %%
X = df_ad[['TV']]
y = df_ad[['sales']]

# %%
from sklearn.linear_model import LinearRegression

# %%
sales_tv_model = LinearRegression()

# %%
sales_tv_model.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
print(sales_tv_model.coef_)
print(sales_tv_model.intercept_)
# Out:
# [[0.04753664]]
# [7.03259355]

# %%
0.04753664 * 50 + 7.03259355
# Out:
# 9.40942555

# %%
X_new = pd.DataFrame({'TV':[50]})
X_new.head()
# Out:
#    TV
# 0  50

# %%
y_pred_tv =sales_tv_model.predict(X_new)

# %%
y_pred_tv
# Out:
# array([[9.40942557]])

# %%
X_new1 = pd.DataFrame({'TV':[df_ad.TV.min(), df_ad.TV.max()]})
X_new1.head()
# Out:
#       TV
# 0    0.7
# 1  296.4

# %%
y_pred_tv1 = sales_tv_model.predict(X_new1)
y_pred_tv1
# Out:
# array([[ 7.0658692 ],
#        [21.12245377]])

# %%
sns.scatterplot(data=df_ad, x='TV', y='sales')
plt.plot(X_new1, y_pred_tv1, c='red', linewidth=2)
plt.show()

# %%
from sklearn.metrics import r2_score, mean_squared_error

# %%
y_pred =sales_tv_model.predict(X)

# %%
r2_score(y_pred=y_pred, y_true=y)
# Out:
# 0.611875050850071

# %%
mean_squared_error(y_pred=y_pred, y_true=y)
# Out:
# 10.512652915656757

# %%
np.sqrt(mean_squared_error(y_pred=y_pred, y_true=y))
# Out:
# 3.2423221486546887

# %%
### TV + radio

# %%
X_tv_radio = df_ad[['TV','radio']]
y = df_ad[['sales']]

# %%
from sklearn.linear_model import LinearRegression

# %%
sales_tv_rad_model = LinearRegression()

# %%
sales_tv_rad_model.fit(X_tv_radio,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
print(sales_tv_rad_model.coef_)
print(sales_tv_rad_model.intercept_)
# Out:
# [[0.04575482 0.18799423]]
# [2.92109991]

# %%
y_pred_tv_rad = sales_tv_rad_model.predict(X_tv_radio)
y_pred_tv_rad
# Out:
# array([[20.55546463],
#        [12.34536229],
#        [12.33701773],
#        [17.61711596],
#        [13.22390813],
#        [12.51208449],
#        [11.71821241],
#        [12.10551553],
#        [ 3.7093792 ],
#        [12.55169696],
#        [ 7.0358597 ],
#        [17.25652015],
#        [10.60866187],
#        [ 8.81095051],
#        [18.44466773],
#        [20.82891539],
#        [12.90386507],
#        [23.24107626],
#        [ 9.94121476],
#        [14.15384619],
#        [18.12139161],
#        [14.74206357],
#        [ 6.51417168],
#        [16.54402663],
#        [ 8.14035215],
#        [15.6080206 ],
#        [14.96769383],
#        [17.0463346 ],
#        [19.39954145],
#        [ 9.15929748],
#        [21.64292187],
#        [11.35791808],
#        [ 7.65045928],
#        [18.83346334],
#        [ 7.56302763],
#        [16.99280099],
#        [23.36720719],
#        [15.6258994 ],
#        [ 9.91257829],
#        [20.4405801 ],
#        [16.37872122],
# ...

# %%
from sklearn.metrics import r2_score, mean_squared_error

# %%
r2_score(y_pred=y_pred_tv_rad, y_true=y)
# Out:
# 0.8971942610828956

# %%
mean_squared_error(y_pred=y_pred_tv_rad, y_true=y)
# Out:
# 2.784569900338092

# %%
## TV + radio + newspaper

# %%
X_tv_rad_np = df_ad[['TV','radio','newspaper']]
y = df_ad[['sales']]

# %%
from sklearn.linear_model import LinearRegression

# %%
sales_tv_rad_np_model = LinearRegression()

# %%
sales_tv_rad_np_model.fit(X_tv_rad_np,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
print(sales_tv_rad_np_model.coef_)
print(sales_tv_rad_np_model.intercept_)
# Out:
# [[ 0.04576465  0.18853002 -0.00103749]]
# [2.93888937]

# %%
y_pred_tv_rad_np = sales_tv_rad_np_model.predict(X_tv_rad_np)
y_pred_tv_rad_np
# Out:
# array([[20.52397441],
#        [12.33785482],
#        [12.30767078],
#        [17.59782951],
#        [13.18867186],
#        [12.47834763],
#        [11.72975995],
#        [12.12295317],
#        [ 3.72734086],
#        [12.55084872],
#        [ 7.0322992 ],
#        [17.28512918],
#        [10.57712073],
#        [ 8.82630048],
#        [18.43436638],
#        [20.81929952],
#        [12.82365674],
#        [23.22495716],
#        [ 9.95168206],
#        [14.16607293],
#        [18.10076728],
#        [14.7405382 ],
#        [ 6.4891503 ],
#        [16.5459329 ],
#        [ 8.14651887],
#        [15.6100386 ],
#        [14.98951429],
#        [17.05167344],
#        [19.41053803],
#        [ 9.14402389],
#        [21.6339338 ],
#        [11.3460929 ],
#        [ 7.63888314],
#        [18.86426829],
#        [ 7.57483051],
#        [17.00682618],
#        [23.40590052],
#        [15.62347779],
#        [ 9.90868103],
#        [20.44761039],
#        [16.37766467],
# ...

# %%
from sklearn.metrics import r2_score, mean_squared_error

# %%
r2_score(y_pred=y_pred_tv_rad_np, y_true=y)
# Out:
# 0.8972106381789522

# %%
mean_squared_error(y_pred=y_pred_tv_rad_np, y_true=y)
# Out:
# 2.784126314510936

# %%
#### trying the stats_model

# %%
#import stats.models.formula.api as smf
from statsmodels.formula.api import ols
sm_sales_tv_model =ols(formula = 'sales ~TV', data=df_ad).fit()
sm_sales_tv_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared:                       0.612
# Model:                            OLS   Adj. R-squared:                  0.610
# Method:                 Least Squares   F-statistic:                     312.1
# Date:                Sun, 05 Sep 2021   Prob (F-statistic):           1.47e-42
# Time:                        17:17:16   Log-Likelihood:                -519.05
# No. Observations:                 200   AIC:                             1042.
# Df Residuals:                     198   BIC:                             1049.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      7.0326      0.458     15.360      0.000       6.130       7.935
# ...

# %%
from statsmodels.formula.api import ols
sm_sales_tv_rad_model = ols(formula = 'sales ~TV + radio', data = df_ad).fit()
sm_sales_tv_rad_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     859.6
# Date:                Sun, 05 Sep 2021   Prob (F-statistic):           4.83e-98
# Time:                        17:19:13   Log-Likelihood:                -386.20
# No. Observations:                 200   AIC:                             778.4
# Df Residuals:                     197   BIC:                             788.3
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.9211      0.294      9.919      0.000       2.340       3.502
# ...

# %%
from statsmodels.formula.api import ols
sales_tv_rad_np_model = ols(formula = 'sales ~ TV + radio + newspaper', data=df_ad).fit()
sales_tv_rad_np_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  sales   R-squared:                       0.897
# Model:                            OLS   Adj. R-squared:                  0.896
# Method:                 Least Squares   F-statistic:                     570.3
# Date:                Sun, 05 Sep 2021   Prob (F-statistic):           1.58e-96
# Time:                        17:20:48   Log-Likelihood:                -386.18
# No. Observations:                 200   AIC:                             780.4
# Df Residuals:                     196   BIC:                             793.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      2.9389      0.312      9.422      0.000       2.324       3.554
# ...

# %%
### Build a ML process ###

# %%
# Reading the data

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Advertising.csv')

# %%
df.shape
# Out:
# (200, 4)

# %%
df.isnull().sum()
# Out:
# TV           0
# radio        0
# newspaper    0
# sales        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
# TV           200 non-null float64
# radio        200 non-null float64
# newspaper    200 non-null float64
# sales        200 non-null float64
# dtypes: float64(4)
# memory usage: 6.3 KB

# %%
df.describe()
# Out:
#                TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
# Preprocessing the data

# %%
# data visualization, outliers and coorelation

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df.corr()
# Out:
#                  TV     radio  newspaper     sales
# TV         1.000000  0.054809   0.056648  0.782224
# radio      0.054809  1.000000   0.354104  0.576223
# newspaper  0.056648  0.354104   1.000000  0.228299
# sales      0.782224  0.576223   0.228299  1.000000

# %%
plt.figure(figsize=(5,5))
sns.heatmap(data = df.corr(), square= True, cmap='bwr')
plt.show()

# %%
# build the model

# %%
X = df.drop(['sales'], axis=1)
y=df[['sales']]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test, y_train,y_test = train_test_split(X,y,train_size=0.7, random_state = 42)
# Out:
# C:\Users\SujitSonar\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2179: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (140, 3)
# (140, 1)

# %%
print(X_test.shape)
print(y_test.shape)
# Out:
# (60, 3)
# (60, 1)

# %%
from sklearn.linear_model import LinearRegression

# %%
model =LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
## testing with the traning data set

# %%
y_train_pred = model.predict(X_train)
y_train_pred
# Out:
# array([[17.39149783],
#        [15.19196153],
#        [11.41650701],
#        [11.20610472],
#        [16.39256165],
#        [ 6.90577778],
#        [21.17740606],
#        [ 6.10528574],
#        [ 9.66662607],
#        [11.67308587],
#        [ 9.0704377 ],
#        [ 6.30582199],
#        [14.7930121 ],
#        [17.42999512],
#        [16.14599956],
#        [16.12273906],
#        [14.9308629 ],
#        [19.61593142],
#        [13.70741553],
#        [21.09067507],
#        [13.09101877],
#        [13.79551693],
#        [ 8.87971636],
#        [16.97348947],
#        [ 8.22902448],
#        [15.34026923],
#        [13.95862675],
#        [23.23157581],
#        [12.67992504],
#        [23.10768546],
#        [ 6.80057243],
#        [18.81832259],
#        [23.69669553],
#        [18.39890879],
#        [16.97890645],
#        [16.44055305],
#        [12.41657918],
#        [11.94072527],
#        [16.7732918 ],
#        [14.5933997 ],
#        [13.22910727],
# ...

# %%
# Test Accuracy of model

# %%
from sklearn.metrics import r2_score,mean_squared_error

# %%
r2_score(y_pred = y_train_pred, y_true = y_train )
# Out:
# 0.9055159502227753

# %%
mean_squared_error(y_pred = y_train_pred, y_true = y_train)
# Out:
# 2.4793551789057875

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [[0.04405928 0.1992875  0.00688245]]
# [2.70894909]

# %%
## testing with the test data set

# %%
X_test.head()
# Out:
#         TV  radio  newspaper
# 95   163.3   31.6       52.9
# 15   195.4   47.7       52.9
# 30   292.9   28.3       43.2
# 158   11.7   36.9       45.2
# 128  220.3   49.0        3.2

# %%
y_pred_test = model.predict(X_test)
y_pred_test
# Out:
# array([[16.5653963 ],
#        [21.18822792],
#        [21.55107058],
#        [10.88923816],
#        [22.20231988],
#        [13.35556872],
#        [21.19692502],
#        [ 7.35028523],
#        [13.27547079],
#        [15.12449511],
#        [ 9.01443026],
#        [ 6.52542825],
#        [14.30205991],
#        [ 8.97026042],
#        [ 9.45679576],
#        [12.00454351],
#        [ 8.91549403],
#        [16.15619251],
#        [10.29582883],
#        [18.72473553],
#        [19.76821818],
#        [13.77469028],
#        [12.49638908],
#        [21.53501762],
#        [ 7.60860741],
#        [ 5.6119801 ],
#        [20.91759483],
#        [11.80627665],
#        [ 9.08076637],
#        [ 8.51412012],
#        [12.17604891],
#        [ 9.9691939 ],
#        [21.73008956],
#        [12.77770578],
#        [18.1011362 ],
#        [20.07590796],
#        [14.26202556],
#        [20.93826535],
#        [10.83938827],
#        [ 4.38190607],
#        [ 9.51332406],
# ...

# %%
r2_score(y_pred=y_pred_test, y_true=y_test)
# Out:
# 0.8609466508230368

# %%
mean_squared_error(y_pred=y_pred_test, y_true=y_test)
# Out:
# 3.7967972367152183

# %%
( #FEATURE selection) , what features need to be inlued in the LM
    
    # Try different models and only keep the predictors that has small p-value
    # check if R2 value goes up when we add new predictors

# %%
# Handling categorical predictors

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
import numpy as np
np.random.seed(12345)

nums = np.random.rand(len(df))
mask_large =nums >0.5

df['Size'] = 'small'
df.loc[mask_large, 'Size'] = 'large'
df.head()
# Out:
#       TV  radio  newspaper  sales   Size
# 0  230.1   37.8       69.2   22.1  large
# 1   44.5   39.3       45.1   10.4  small
# 2   17.2   45.9       69.3    9.3  small
# 3  151.5   41.3       58.5   18.5  small
# 4  180.8   10.8       58.4   12.9  large

# %%
# creating dummy variable

df['IsLarge'] = df.Size.map({'small':0,'large':1})

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales   Size  IsLarge
# 0  230.1   37.8       69.2   22.1  large        1
# 1   44.5   39.3       45.1   10.4  small        0
# 2   17.2   45.9       69.3    9.3  small        0
# 3  151.5   41.3       58.5   18.5  small        0
# 4  180.8   10.8       58.4   12.9  large        1

# %%
feature_cols = ['TV','radio','newspaper','IsLarge']

# %%
X = df[feature_cols]
y= df.sales

# %%
lm = LinearRegression()

# %%
lm.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
zip(feature_cols, lm.coef_)

# %%
np.random.seed(12345)
nums = np.random.rand(len(df))
mask_suburban = (nums >0.33) & (nums < 0.66)
mask_urban = nums > 0.66

df['Area'] ='rural'
df.loc[mask_suburban, 'Area'] = 'suburban'
df.loc[mask_urban, 'Area'] = 'urban'

df.head()
# Out:
#       TV  radio  newspaper  sales   Size  IsLarge      Area
# 0  230.1   37.8       69.2   22.1  large        1     urban
# 1   44.5   39.3       45.1   10.4  small        0     rural
# 2   17.2   45.9       69.3    9.3  small        0     rural
# 3  151.5   41.3       58.5   18.5  small        0     rural
# 4  180.8   10.8       58.4   12.9  large        1  suburban

# %%
area_dummies = pd.get_dummies(df.Area, prefix = 'Area').iloc[:,1:]

# %%
df = pd.concat([df,area_dummies], axis=1)
df.head()
# Out:
#       TV  radio  newspaper  sales   Size  IsLarge      Area  Area_suburban  \
# 0  230.1   37.8       69.2   22.1  large        1     urban              0
# 1   44.5   39.3       45.1   10.4  small        0     rural              0
# 2   17.2   45.9       69.3    9.3  small        0     rural              0
# 3  151.5   41.3       58.5   18.5  small        0     rural              0
# 4  180.8   10.8       58.4   12.9  large        1  suburban              1
#
#    Area_urban
# 0           1
# 1           0
# 2           0
# 3           0
# 4           0

# %%
feature_cols = ['TV','radio','newspaper','IsLarge','Area_suburban','Area_urban']

X = df[feature_cols]
y= df.sales

lm = LinearRegression()
lm.fit(X,y)
print(feature_cols, lm.coef_)
# Out:
# ['TV', 'radio', 'newspaper', 'IsLarge', 'Area_suburban', 'Area_urban'] [ 0.0456175   0.18909888 -0.00164417  0.27237198 -0.52161688 -0.33298681]
